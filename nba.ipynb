# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nba 1.csv')

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head(56)
# Out:
#                        Name                Team  Number Position   Age Height  \
# 0             Avery Bradley      Boston Celtics     0.0       PG  25.0    6-2
# 1               Jae Crowder      Boston Celtics    99.0       SF  25.0    6-6
# 2              John Holland      Boston Celtics    30.0       SG  27.0    6-5
# 3               R.J. Hunter      Boston Celtics    28.0       SG  22.0    6-5
# 4             Jonas Jerebko      Boston Celtics     8.0       PF  29.0   6-10
# 5              Amir Johnson      Boston Celtics    90.0       PF  29.0    6-9
# 6             Jordan Mickey      Boston Celtics    55.0       PF  21.0    6-8
# 7              Kelly Olynyk      Boston Celtics    41.0        C  25.0    7-0
# 8              Terry Rozier      Boston Celtics    12.0       PG  22.0    6-2
# 9              Marcus Smart      Boston Celtics    36.0       PG  22.0    6-4
# 10          Jared Sullinger      Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
def height_to_centemeters(height):
    feet, inches = map(int,height.split("-"))
    height_m=feet*0.3048+inches*0.0254
    height_to_centemeters= height_m*100
    return height_to_centemeters

# %%
df_clean=df.dropna(subset=['Height'])

# %%
def height_to_meters(height):
    try:
        # Ensure the value is a string and split it
        feet, inches = map(int, str(height).split('-'))  
        return feet * 0.3048 + inches * 0.0254  # Convert to meters
    except ValueError:
        return None  # Return None for invalid or missing values
 
# Apply the function to the Height column
df['Height_meters'] = df['Height'].apply(height_to_meters)
 
# Check the updated DataFrame
print("Dataset with numeric Height (in meters):")
print(df[['Name', 'Height', 'Height_meters']])
# Out:
# Dataset with numeric Height (in meters):
#               Name Height  Height_meters
# 0    Avery Bradley    6-2         1.8796
# 1      Jae Crowder    6-6         1.9812
# 2     John Holland    6-5         1.9558
# 3      R.J. Hunter    6-5         1.9558
# 4    Jonas Jerebko   6-10         2.0828
# ..             ...    ...            ...
# 453   Shelvin Mack    6-3         1.9050
# 454      Raul Neto    6-1         1.8542
# 455   Tibor Pleiss    7-3         2.2098
# 456    Jeff Withey    7-0         2.1336
# 457            NaN    NaN            NaN
#
# [458 rows x 3 columns]

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Height_meters
# ...

# %%
df.drop(columns=['Height'],inplace= True)

# %%
df
# Out:
#               Name            Team  Number Position   Age  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0
# ..             ...             ...     ...      ...   ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0   231.0
# 457            NaN             NaN     NaN      NaN   NaN     NaN
#
#                College     Salary  Height_meters
# 0                Texas  7730337.0         1.8796
# 1            Marquette  6796117.0         1.9812
# ...

# %%
# Group by College and calculate average salary
college_salary = df.groupby("College")["Salary"].mean().sort_values(ascending=False)
print(college_salary)
# Out:
# College
# Oklahoma             1.890773e+07
# Louisiana Tech       1.867166e+07
# San Diego State      1.640750e+07
# Marquette            1.198129e+07
# Texas A&M            1.177876e+07
#                          ...
# Iowa State           1.698830e+05
# UC Santa Barbara     6.955950e+04
# Boston University             NaN
# Detroit                       NaN
# Rhode Island                  NaN
# Name: Salary, Length: 118, dtype: float64

# %%
df.dtypes
# Out:
# Name              object
# Team              object
# Number           float64
# Position          object
# Age              float64
# Weight           float64
# College           object
# Salary           float64
# Height_meters    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name              1
# Team              1
# Number            1
# Position          1
# Age               1
# Weight            1
# College          85
# Salary           12
# Height_meters     1
# dtype: int64

# %%
df.dropna(subset=['Name','Team','Number','Position','Age','Height_meters'], inplace = True)

# %%
# Replace missing values in the "College" column with "Unknown"
df["College"].fillna("Unknown" , inplace = True)

# Replace missing values in the "Salary" column with the mean of the "Salary" column
df["Salary"].fillna(df["Salary"].median(), inplace=True)
# Out:
# /var/folders/hk/jrmj5krn1m13rs2ldn9zl6q40000gn/T/ipykernel_1696/1247867138.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["College"].fillna("Unknown" , inplace = True)
# /var/folders/hk/jrmj5krn1m13rs2ldn9zl6q40000gn/T/ipykernel_1696/1247867138.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# Name             0
# Team             0
# Number           0
# Position         0
# Age              0
# Weight           0
# College          0
# Salary           0
# Height_meters    0
# dtype: int64

# %%
# Plotting
plt.figure(figsize=(10, 6))
college_salary.head(10).plot(kind="bar", color="skyblue", edgecolor="black")

# Adding labels and title
plt.title("Average Salary by College", fontsize=16)
plt.xlabel("College", fontsize=12)
plt.ylabel("Average Salary ($)", fontsize=12)
plt.xticks(rotation=45, ha="right", fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %%
df
# Out:
#               Name            Team  Number Position   Age  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0
# ..             ...             ...     ...      ...   ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0   231.0
#
#                College     Salary  Height_meters
# 0                Texas  7730337.0         1.8796
# 1            Marquette  6796117.0         1.9812
# ...

# %%
df_sorted_descending = df.sort_values(by="Salary", ascending=False)

# %%
df_sorted_descending
# Out:
#                        Name                  Team  Number Position   Age  \
# 109             Kobe Bryant    Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James   Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony       New York Knicks     7.0       SF  32.0
# 251           Dwight Howard       Houston Rockets    12.0        C  30.0
# 339              Chris Bosh            Miami Heat     1.0       PF  32.0
# ..                      ...                   ...     ...      ...   ...
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#      Weight           College      Salary  Height_meters
# ...

# %%
df_sorted_ascending = df.sort_values(by="Age")

# %%
df_sorted_ascending
# Out:
#                    Name                    Team  Number Position   Age  \
# 226       Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0
# 122        Devin Booker            Phoenix Suns     1.0       SG  19.0
# 40   Kristaps Porzingis         New York Knicks     6.0       PF  20.0
# 401          Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0
# 427     Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0
# ..                  ...                     ...     ...      ...   ...
# 261        Vince Carter       Memphis Grizzlies    15.0       SG  39.0
# 102      Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0
# 298          Tim Duncan       San Antonio Spurs    21.0        C  40.0
# 400       Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0
# 304        Andre Miller       San Antonio Spurs    24.0       PG  40.0
#
#      Weight         College     Salary  Height_meters
# 226   202.0            UNLV  1733040.0         1.9812
# ...

# %%
Age_LT25 = df[df['Age'] < 25]
df_selected = Age_LT25[['Name', 'Team','Age','College','Salary']]
df_selected
# Out:
#                 Name            Team   Age         College      Salary
# 3        R.J. Hunter  Boston Celtics  22.0   Georgia State   1148640.0
# 6      Jordan Mickey  Boston Celtics  21.0             LSU   1170960.0
# 8       Terry Rozier  Boston Celtics  22.0      Louisville   1824360.0
# 9       Marcus Smart  Boston Celtics  22.0  Oklahoma State   3431040.0
# 10   Jared Sullinger  Boston Celtics  24.0      Ohio State   2569260.0
# ..               ...             ...   ...             ...         ...
# 446   Derrick Favors       Utah Jazz  24.0    Georgia Tech  12000000.0
# 447      Rudy Gobert       Utah Jazz  23.0         Unknown   1175880.0
# 449      Rodney Hood       Utah Jazz  23.0            Duke   1348440.0
# 452       Trey Lyles       Utah Jazz  20.0        Kentucky   2239800.0
# 454        Raul Neto       Utah Jazz  24.0         Unknown    900000.0
#
# [154 rows x 5 columns]

# %%
Age_LT20_to_30 = df[(df['Age'] < 30) & (df['Age'] > 20)]

# %%
Age_LT20_to_30_bol = Age_LT20_to_30[(Age_LT20_to_30['Team'] =='Boston Celtics')]

# %%
Age_LT20_to_30_bol_sal50mil=Age_LT25 = Age_LT20_to_30_bol[Age_LT20_to_30_bol['Salary'] >= 5000000]

# %%
Age_LT20_to_30_bol_sal50mil
# Out:
#              Name            Team  Number Position   Age  Weight     College  \
# 0   Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0       Texas
# 1     Jae Crowder  Boston Celtics    99.0       SF  25.0   235.0   Marquette
# 4   Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0     Unknown
# 5    Amir Johnson  Boston Celtics    90.0       PF  29.0   240.0     Unknown
# 11  Isaiah Thomas  Boston Celtics     4.0       PG  27.0   185.0  Washington
#
#         Salary  Height_meters
# 0    7730337.0         1.8796
# 1    6796117.0         1.9812
# 4    5000000.0         2.0828
# 5   12000000.0         2.0574
# 11   6912869.0         1.7526

# %%
Age_LT20_to_30 = df[(df['Age'] < 30) & (df['Age'] > 20)]
Age_LT20_to_30_bol = Age_LT20_to_30[(Age_LT20_to_30['Team'] =='Boston Celtics')]
Age_LT20_to_30_bol_sal50mil=Age_LT25 = Age_LT20_to_30_bol[Age_LT20_to_30_bol['Salary'] >= 5000000]
Age_LT20_to_30_bol_sal50mil
# Out:
#              Name            Team  Number Position   Age  Weight     College  \
# 0   Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0       Texas
# 1     Jae Crowder  Boston Celtics    99.0       SF  25.0   235.0   Marquette
# 4   Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0     Unknown
# 5    Amir Johnson  Boston Celtics    90.0       PF  29.0   240.0     Unknown
# 11  Isaiah Thomas  Boston Celtics     4.0       PG  27.0   185.0  Washington
#
#         Salary  Height_meters
# 0    7730337.0         1.8796
# 1    6796117.0         1.9812
# 4    5000000.0         2.0828
# 5   12000000.0         2.0574
# 11   6912869.0         1.7526

# %%
# Function to convert weight from lbs to kg
def weight_to_kg(weight_lbs):
    return weight_lbs * 0.453592

# Function to calculate BMI
def calculate_bmi(row):
    weight_kg = weight_to_kg(row['Weight'])
    height_m = row['Height_meters']
    bmi = weight_kg / (height_m ** 2)
    return bmi

# Add a new column 'BMI' based on existing columns
df['BMI'] = df.apply(calculate_bmi, axis=1)

# Print the updated DataFrame
df
# Out:
#               Name            Team  Number Position   Age  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0
# ..             ...             ...     ...      ...   ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0   231.0
#
#                College     Salary  Height_meters        BMI
# 0                Texas  7730337.0         1.8796  23.110376
# ...

# %%
df['Experience'] = df['Age']-16

# %%
df
# Out:
#               Name            Team  Number Position   Age  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0
# ..             ...             ...     ...      ...   ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0   231.0
#
#                College     Salary  Height_meters        BMI  Experience
# 0                Texas  7730337.0         1.8796  23.110376         9.0
# ...

# %%
pd.set_option('display.float_format', '${:.0f}'.format)
average_salary_by_college = df.groupby('College')['Salary'].mean()

# %%
average_salary_by_college
# Out:
# College
# Alabama            $1421686
# Arizona            $3325948
# Arizona State      $7933941
# Arkansas           $2713180
# Baylor              $981348
#                      ...
# Western Michigan    $845059
# Wichita State       $845059
# Wisconsin          $1974492
# Wyoming            $1155600
# Xavier             $1499187
# Name: Salary, Length: 119, dtype: float64

# %%
df_sorted_descending = average_salary_by_college.sort_values(ascending=False)

# %%
df_sorted_descending
# Out:
# College
# Oklahoma           $18907726
# Louisiana Tech     $18671659
# San Diego State    $16407500
# Marquette          $11981289
# Texas A&M          $11778759
#                       ...
# Rider                $245177
# Western Carolina     $200600
# Charleston           $200600
# Iowa State           $169883
# UC Santa Barbara      $69560
# Name: Salary, Length: 119, dtype: float64

# %%
pd.DataFrame(df_sorted_descending)
# Out:
#                     Salary
# College
# Oklahoma         $18907726
# Louisiana Tech   $18671659
# San Diego State  $16407500
# Marquette        $11981289
# Texas A&M        $11778759
# ...                    ...
# Rider              $245177
# Western Carolina   $200600
# Charleston         $200600
# Iowa State         $169883
# UC Santa Barbara    $69560
#
# [119 rows x 1 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
average_salary_by_college = df.groupby('College')['Salary'].mean()
df_sorted_descending = average_salary_by_college.sort_values(ascending=False)
pd.DataFrame(df_sorted_descending)
# Out:
#                       Salary
# College
# Oklahoma         18907726.00
# Louisiana Tech   18671659.00
# San Diego State  16407500.00
# Marquette        11981288.80
# Texas A&M        11778758.67
# ...                      ...
# Rider              245177.00
# Western Carolina   200600.00
# Charleston         200600.00
# Iowa State         169883.00
# UC Santa Barbara    69559.50
#
# [119 rows x 1 columns]

# %%
pd.set_option('display.float_format', '{:.0f}'.format)
median_age_by_Teams = df.groupby('Team')['Age'].median()
pd.DataFrame(median_age_by_Teams)
# Out:
#                         Age
# Team
# Atlanta Hawks            27
# Boston Celtics           25
# Brooklyn Nets            26
# Charlotte Hornets        27
# Chicago Bulls            27
# Cleveland Cavaliers      30
# Dallas Mavericks         31
# Denver Nuggets           25
# Detroit Pistons          25
# Golden State Warriors    28
# Houston Rockets          27
# Indiana Pacers           27
# Los Angeles Clippers     29
# Los Angeles Lakers       27
# Memphis Grizzlies        28
# Miami Heat               30
# Milwaukee Bucks          24
# Minnesota Timberwolves   25
# New Orleans Pelicans     27
# New York Knicks          26
# Oklahoma City Thunder    26
# Orlando Magic            24
# Philadelphia 76ers       24
# Phoenix Suns             25
# Portland Trail Blazers   24
# Sacramento Kings         27
# San Antonio Spurs        33
# Toronto Raptors          25
# Utah Jazz                24
# Washington Wizards       29

# %%
# Assuming median_age_by_Teams is your DataFrame
median_age_by_Teams.sort_values()
pd.DataFrame(median_age_by_Teams.sort_values())
# Out:
#                         Age
# Team
# Portland Trail Blazers   24
# Philadelphia 76ers       24
# Utah Jazz                24
# Orlando Magic            24
# Milwaukee Bucks          24
# Boston Celtics           25
# Toronto Raptors          25
# Minnesota Timberwolves   25
# Denver Nuggets           25
# Detroit Pistons          25
# Phoenix Suns             25
# Brooklyn Nets            26
# New York Knicks          26
# Oklahoma City Thunder    26
# New Orleans Pelicans     27
# Atlanta Hawks            27
# Indiana Pacers           27
# Sacramento Kings         27
# Chicago Bulls            27
# Charlotte Hornets        27
# Los Angeles Lakers       27
# Houston Rockets          27
# Memphis Grizzlies        28
# Golden State Warriors    28
# Los Angeles Clippers     29
# Washington Wizards       29
# Cleveland Cavaliers      30
# Miami Heat               30
# Dallas Mavericks         31
# San Antonio Spurs        33

# %%
pd.set_option('display.float_format', '${:.0f}'.format)
average_salary_by_position = df.groupby('Position')['Salary'].mean()

# %%
average_salary_by_position.sort_values()
# Out:
# Position
# SG   $3975426
# PF   $4510781
# SF   $4833648
# PG   $4980492
# C    $5967052
# Name: Salary, dtype: float64

# %%
average_salary_by_position = df.groupby('Position')['Salary'].describe()
average_salary_by_position
# Out:
#           count     mean      std     min      25%      50%      75%       max
# Position
# C           $78 $5967052 $5787989  $83397 $1328880 $3811060 $9620558 $22359364
# PF         $100 $4510781 $4735992 $111444 $1123722 $2877470 $5543725 $22192730
# PG          $92 $4980492 $4960818  $55722 $1448610 $2927470 $7000000 $21468695
# SF          $85 $4833648 $5980005  $30888 $1000000 $2041080 $5500000 $25000000
# SG         $102 $3975426 $4428862  $55722  $947276 $2394102 $5675000 $20000000
